# %% [markdown]
# <a href="https://colab.research.google.com/github/Th4End/TP_ANN_Titanic/blob/main/FouilleDonnee/ANN/TP_ANN_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP : Classification Binaire avec PyTorch – Titanic
#
# ## **Objectif du TP**
# Prédire si un passager du Titanic a **survécu ou non** à partir de ses caractéristiques (âge, sexe, classe, etc.) en utilisant un **réseau de neurones fully-connected** avec **PyTorch**.
#
# ---
#
# ## **Compétences abordées**
#
# | Thème | Détail |
# |------|--------|
# | **Préparation des données** | Chargement, nettoyage, split train/dev |
# | **PyTorch Dataset & DataLoader** | Gestion efficace des batchs |
# | **Modèle personnalisé** | `nn.Module`, couches cachées, dropout, ReLU |
# | **Boucle d'entraînement** | `optimizer.zero_grad()`, `loss.backward()` |
# | **Évaluation** | Accuracy, CrossEntropyLoss |
# | **Soumission Kaggle** | Format CSV |
# | **(Bonus)** | Grid Search + Validation Croisée |
#
# ---
#
# ## **Consignes**
# - Complétez **chaque cellule de code** en suivant les instructions en **Markdown**.
# - Les **imports sont fournis**.
# - Testez à chaque étape !
# - **Bonus optionnel** en fin de TP.
# - Vous pouvez interroger un LLM pour déboguer votre modèle, mais vous devez expliquer les modifications proposées et pourquoi vous les acceptez ou non.
# ---
#
# **Bon courage !**

# %% [markdown]
# ## **0. Imports (déjà fournis)**
#
# Exécutez cette cellule **sans modification**.

# %%
import numpy as np
import polars as pl
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, ParameterGrid
import matplotlib.pyplot as plt
import csv
import os

# Device (GPU si disponible)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device utilisé : {DEVICE}")
# Out:
# Device utilisé : cpu

# %% [markdown]
# ## **1. Hyperparamètres**
#
# Définissez les hyperparamètres du modèle. Vous les modifierez plus tard pour améliorer les performances.

# %%
HIDDEN_SIZE =  50
NUM_LAYERS = 3
DROPOUT_PROB = 0.2
LEARNING_RATE = 0.01
NUM_EPOCHS =  50
BATCH_SIZE =  50

# %% [markdown]
# ## **2. Chargement et préparation des données**
#
# - Chargez `train_clean.csv` et `test_clean.csv`
# - Extrayez :
#   - `X` : toutes les colonnes **à partir de la 3e** (index 2)
#   - `y` : la colonne **Survived** (index 1)
# - Convertissez en `np.float32` pour `X` et `np.int64` pour `y`
# - Séparez en `train` (90%) et `dev` (10%) avec `stratify=y` et `random_state=42`
#
# **À compléter**

# %%
df_train = pl.read_csv("/content/sample_data/train_clean.csv")
df_test = pl.read_csv("/content/sample_data/test_clean.csv")


X = df_train.select(df_train.columns[2:]).to_numpy().astype(np.float32)
y = df_train.select(df_train.columns[1]).to_numpy().ravel().astype(np.int64)

X_train, X_dev, y_train, y_dev = train_test_split(
    X,
    y,
    test_size=0.1,
    stratify=y,
    random_state=42
)
print(df_train.head())
print(df_test.head())
# Out:
# shape: (5, 9)
# ┌─────────────┬──────────┬────────┬─────┬───┬──────┬──────────┬─────────┬───────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Sex ┆ … ┆ Fare ┆ Embarked ┆ IsAlone ┆ Title │
# │ ---         ┆ ---      ┆ ---    ┆ --- ┆   ┆ ---  ┆ ---      ┆ ---     ┆ ---   │
# │ i64         ┆ i64      ┆ i64    ┆ i64 ┆   ┆ i64  ┆ i64      ┆ i64     ┆ i64   │
# ╞═════════════╪══════════╪════════╪═════╪═══╪══════╪══════════╪═════════╪═══════╡
# │ 1           ┆ 0        ┆ 3      ┆ 1   ┆ … ┆ 0    ┆ 0        ┆ 0       ┆ 1     │
# │ 2           ┆ 1        ┆ 1      ┆ 0   ┆ … ┆ 3    ┆ 1        ┆ 0       ┆ 3     │
# │ 3           ┆ 1        ┆ 3      ┆ 0   ┆ … ┆ 1    ┆ 0        ┆ 1       ┆ 2     │
# │ 4           ┆ 1        ┆ 1      ┆ 0   ┆ … ┆ 3    ┆ 0        ┆ 0       ┆ 3     │
# │ 5           ┆ 0        ┆ 3      ┆ 1   ┆ … ┆ 1    ┆ 0        ┆ 1       ┆ 1     │
# └─────────────┴──────────┴────────┴─────┴───┴──────┴──────────┴─────────┴───────┘
# shape: (5, 8)
# ┌─────────────┬────────┬─────┬─────┬──────┬──────────┬─────────┬───────┐
# │ PassengerId ┆ Pclass ┆ Sex ┆ Age ┆ Fare ┆ Embarked ┆ IsAlone ┆ Title │
# │ ---         ┆ ---    ┆ --- ┆ --- ┆ ---  ┆ ---      ┆ ---     ┆ ---   │
# │ i64         ┆ i64    ┆ i64 ┆ i64 ┆ i64  ┆ i64      ┆ i64     ┆ i64   │
# ╞═════════════╪════════╪═════╪═════╪══════╪══════════╪═════════╪═══════╡
# │ 892         ┆ 3      ┆ 1   ┆ 2   ┆ 0    ┆ 2        ┆ 1       ┆ 1     │
# │ 893         ┆ 3      ┆ 0   ┆ 2   ┆ 0    ┆ 0        ┆ 0       ┆ 3     │
# │ 894         ┆ 2      ┆ 1   ┆ 3   ┆ 1    ┆ 2        ┆ 1       ┆ 1     │
# │ 895         ┆ 3      ┆ 1   ┆ 1   ┆ 1    ┆ 0        ┆ 1       ┆ 1     │
# │ 896         ┆ 3      ┆ 0   ┆ 1   ┆ 1    ┆ 0        ┆ 0       ┆ 3     │
# └─────────────┴────────┴─────┴─────┴──────┴──────────┴─────────┴───────┘

# %% [markdown]
# ## **3. Dataset PyTorch**
#
# Créez une classe `TitanicDataset` qui hérite de `torch.utils.data.Dataset`.
#
# Elle doit :
# - Accepter `X` et `y` (optionnel)
# - Convertir les données en tenseurs PyTorch
# - Implémenter `__len__` et `__getitem__`
#
# **À compléter**

# %%
import torch
from torch.utils.data import Dataset

class TitanicDataset(Dataset):
    def __init__(self, X, y=None):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.int64) if y is not None else None
        self.n_samples = self.X.shape[0]

    def __len__(self):
        return self.n_samples

    def __getitem__(self, index):
        if self.y is not None:
            return self.X[index], self.y[index]
        else:
            return self.X[index]

# %% [markdown]
# ## **4. DataLoaders**
#
# Créez trois `DataLoader` :
# - `train_loader` → `shuffle=True`
# - `dev_loader` → `shuffle=False`
# - `test_loader` → données de test (sans `y`)
#
# **À compléter**

# %%
X_test = df_test.select(
    df_test.columns[2:]
    ).to_numpy().astype(np.float32)

train_dataset = TitanicDataset(X_train, y_train)
dev_dataset = TitanicDataset(X_dev, y_dev)
test_dataset = TitanicDataset(X_test)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

dev_loader = DataLoader(
    dev_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %% [markdown]
# ## **5. Modèle : Réseau de neurones**
#
# Créez une classe `TitanicModel` avec :
# - `num_layers` couches cachées de taille `hidden_size`
# - Activation **ReLU**
# - **Dropout** après chaque couche cachée
# - Sortie : 2 classes (utilisez `nn.Linear` final)
# - Utilisez `nn.Sequential` pour construire le réseau
#
# **À compléter**

# %%
class TitanicModel(nn.Module):
    def __init__(self, input_size, hidden_size=50, num_layers=3, dropout=0.2, num_classes=2):
        super().__init__()

        layers = []
        in_features = input_size

        for i in range(num_layers):
            layers.append(nn.Linear(in_features, hidden_size))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout))
            in_features = hidden_size

        layers.append(nn.Linear(hidden_size, num_classes))

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# %% [markdown]
# ## **6. Fonction de coût et optimiseur**
#
# - `criterion` : `CrossEntropyLoss`
# - `optimizer` : `Adam` avec le `learning_rate` défini
#
# **À compléter**

# %%
HIDDEN_SIZE = 50
NUM_LAYERS = 3
DROPOUT_PROB = 0.2
LEARNING_RATE = 0.01

input_size = X_train.shape[1]

model = TitanicModel(
    input_size=input_size,
    hidden_size=HIDDEN_SIZE,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT_PROB
)

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=LEARNING_RATE
)

# %% [markdown]
# ## **7. Boucle d'entraînement (1 epoch)**
#
# Écrivez une fonction `train_epoch` qui :
# - Met le modèle en mode `.train()`
# - Parcourt les batchs
# - Calcule la perte, fait `backward()` et `step()`
# - Retourne la **perte moyenne**
#
# **À compléter**

# %%
def train_epoch(model, dataloader, criterion, optimizer, device="cpu"):
    model.train()
    running_loss = 0.0
    total_batches = 0

    for X_batch, y_batch in dataloader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        total_batches += 1

    return running_loss / total_batches

# %% [markdown]
# ## **8. Évaluation**
#
# Écrivez une fonction `evaluate` qui :
# - Met le modèle en `.eval()`
# - Désactive le gradient (`torch.no_grad()`)
# - Calcule l'**accuracy** sur le dataset de validation
#
# **À compléter**

# %%
def evaluate(model, dataloader, device="cpu"):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for X_batch, y_batch in dataloader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            outputs = model(X_batch)
            _, predicted = torch.max(outputs, dim=1)

            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()

    return correct / total

# %% [markdown]
# ## **9. Entraînement complet**
#
# Boucle sur `NUM_EPOCHS` :
# - Appel à `train_epoch`
# - Toutes les 10 epochs : afficher l'accuracy sur `dev`
#
# **À compléter**

# %%
for epoch in range(1, NUM_EPOCHS + 1):
    loss = train_epoch(model, train_loader, criterion, optimizer)

    if epoch % 10 == 0 or epoch == 1:
        acc_dev = evaluate(model, dev_loader)
        print(f"Epoch {epoch}/{NUM_EPOCHS} - Loss: {loss:.4f} - Dev Accuracy: {acc_dev:.4f}")
print("X_train.shape:", X_train.shape)
print("X_test.shape:", X_test.shape)
# Out:
# Epoch 1/50 - Loss: 0.4185 - Dev Accuracy: 0.7444
# Epoch 10/50 - Loss: 0.3950 - Dev Accuracy: 0.7778
# Epoch 20/50 - Loss: 0.4329 - Dev Accuracy: 0.7889
# Epoch 30/50 - Loss: 0.4232 - Dev Accuracy: 0.7778
# Epoch 40/50 - Loss: 0.4103 - Dev Accuracy: 0.7889
# Epoch 50/50 - Loss: 0.5377 - Dev Accuracy: 0.7667
# X_train.shape: (801, 7)
# X_test.shape: (418, 6)

# %% [markdown]
# ## **10. Prédiction sur le test & Soumission Kaggle (Optionnel)**
#
# - Passez le modèle en `.eval()`
# - Parcourez `test_loader`
# - Récupérez les prédictions avec `torch.max(..., 1)`
# - Générez `submission.csv` avec `PassengerId` et `Survived`
#
# **À compléter**

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval()

feature_cols = df_train.columns[2:]
X_test_aligned = df_test.select(feature_cols).to_numpy().astype(np.float32)
test_dataset = TitanicDataset(X_test_aligned)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

all_preds = []

with torch.no_grad():
    for X_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())

submission = pl.DataFrame({
    "PassengerId": df_test.select("PassengerId").to_numpy().ravel(),
    "Survived": all_preds
})

submission.write_csv("submission.csv")
print("submission.csv créé !")
# Out:
# submission.csv créé !

# %% [markdown]
# ## **EXERCICE BONUS (OPTIONNEL)**
#
# ### **Grid Search + Validation Croisée**
#
# > **Objectif** : Trouver automatiquement les meilleurs hyperparamètres.
#
# **À faire (seulement si vous avez fini !)**
#
# 1. Utilisez `KFold` pour diviser les données
# 2. Testez plusieurs valeurs de :
#    - `learning_rate`
#    - `dropout_prob`
#    - `hidden_size`
# 3. Entraînez un modèle pour chaque combinaison
# 4. Gardez le modèle avec la **meilleure accuracy moyenne**
#
# **Indice** : Utilisez `ParameterGrid` de `sklearn`
#
# ---
#
# **Question** : Pourquoi le Grid Search est-il utile ? Donnez un exemple de compromis entre `dropout` élevé et sous-apprentissage.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

param_grid = {
    "learning_rate": [0.01, 0.001],
    "dropout_prob": [0.2, 0.5],
    "hidden_size": [50, 100]
}

grid = list(ParameterGrid(param_grid))
best_acc = 0.0
best_params = None
best_model_state = None

X_all = df_train.select(df_train.columns[2:]).to_numpy().astype(np.float32)
y_all = df_train.select("Survived").to_numpy().ravel().astype(np.int64)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

for params in grid:
    accs = []
    for train_index, val_index in kf.split(X_all):
        X_train_cv, X_val_cv = X_all[train_index], X_all[val_index]
        y_train_cv, y_val_cv = y_all[train_index], y_all[val_index]

        train_dataset = TitanicDataset(X_train_cv, y_train_cv)
        val_dataset = TitanicDataset(X_val_cv, y_val_cv)

        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

        model = TitanicModel(
            input_size=X_all.shape[1],
            hidden_size=params["hidden_size"],
            num_layers=NUM_LAYERS,
            dropout=params["dropout_prob"]
        ).to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=params["learning_rate"])
        for epoch in range(5):
            model.train()
            for X_batch, y_batch in train_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                optimizer.zero_grad()
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                loss.backward()
                optimizer.step()
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                outputs = model(X_batch)
                _, preds = torch.max(outputs, 1)
                correct += (preds == y_batch).sum().item()
                total += y_batch.size(0)
        accs.append(correct / total)

    mean_acc = np.mean(accs)
    print(f"Params: {params} - Mean Accuracy: {mean_acc:.4f}")

    if mean_acc > best_acc:
        best_acc = mean_acc
        best_params = params
        best_model_state = model.state_dict()

print("Best Params:", best_params)
print("Best Accuracy:", best_acc)
# Out:
# Params: {'dropout_prob': 0.2, 'hidden_size': 50, 'learning_rate': 0.01} - Mean Accuracy: 0.7958
# Params: {'dropout_prob': 0.2, 'hidden_size': 50, 'learning_rate': 0.001} - Mean Accuracy: 0.7610
# Params: {'dropout_prob': 0.2, 'hidden_size': 100, 'learning_rate': 0.01} - Mean Accuracy: 0.7980
# Params: {'dropout_prob': 0.2, 'hidden_size': 100, 'learning_rate': 0.001} - Mean Accuracy: 0.8002
# Params: {'dropout_prob': 0.5, 'hidden_size': 50, 'learning_rate': 0.01} - Mean Accuracy: 0.7969
# Params: {'dropout_prob': 0.5, 'hidden_size': 50, 'learning_rate': 0.001} - Mean Accuracy: 0.7285
# Params: {'dropout_prob': 0.5, 'hidden_size': 100, 'learning_rate': 0.01} - Mean Accuracy: 0.7913
# Params: {'dropout_prob': 0.5, 'hidden_size': 100, 'learning_rate': 0.001} - Mean Accuracy: 0.7587
# Best Params: {'dropout_prob': 0.2, 'hidden_size': 100, 'learning_rate': 0.001}
# Best Accuracy: 0.8002448057246877

# %% [markdown]
# # Task
# Load the "train_clean.csv" and "test_clean.csv" datasets using Polars. From the training data, extract features `X` from the 3rd column onwards (index 2) and the target `y` from the "Survived" column (index 1). Convert `X` to `np.float32` and `y` to `np.int64`. Split the training data into 90% train and 10% dev sets, stratifying by `y` and using `random_state=42`. Finally, extract features `X_test` from the test data (from the 3rd column onwards, index 2) and convert them to `np.float32`.

# %% [markdown]
# ## load_data
#
# ### Subtask:
# Load train_clean.csv and test_clean.csv using polars.

# %% [markdown]
# **Reasoning**:
# The subtask is to load `train_clean.csv` and `test_clean.csv` into Polars DataFrames. I will replace the incorrect file loading in the existing code cell with the correct one, assuming the files are directly in the `/content/` directory for now. If they are located elsewhere, the user will need to adjust the path.

# %%
df_train = pl.read_csv("/content/train_clean.csv")
df_test = pl.read_csv("/content/test_clean.csv")

print("df_train loaded successfully.")
print("df_test loaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3616633908.py in <cell line: 0>()
# ----> 1 df_train = pl.read_csv("/content/train_clean.csv")
#       2 df_test = pl.read_csv("/content/test_clean.csv")
#       3
#       4 print("df_train loaded successfully.")
#       5 print("df_test loaded successfully.")
#
# /usr/local/lib/python3.12/dist-packages/polars/_utils/deprecation.py in wrapper(*args, **kwargs)
#     126                 old_name, new_name, kwargs, function.__qualname__, version
#     127             )
# --> 128             return function(*args, **kwargs)
#     129
#     130         wrapper.__signature__ = inspect.signature(function)  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.12/dist-packages/polars/_utils/deprecation.py in wrapper(*args, **kwargs)
#     126                 old_name, new_name, kwargs, function.__qualname__, version
#     127             )
# --> 128             return function(*args, **kwargs)
#     129
#     130         wrapper.__signature__ = inspect.signature(function)  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.12/dist-packages/polars/_utils/deprecation.py in wrapper(*args, **kwargs)
#     126                 old_name, new_name, kwargs, function.__qualname__, version
#     127             )
# --> 128             return function(*args, **kwargs)
#     129
#     130         wrapper.__signature__ = inspect.signature(function)  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.12/dist-packages/polars/io/csv/functions.py in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     547             storage_options=storage_options,
#     548         ) as data:
# --> 549             df = _read_csv_impl(
#     550                 data,
#     551                 has_header=has_header,
#
# /usr/local/lib/python3.12/dist-packages/polars/io/csv/functions.py in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, skip_lines, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     695     projection, columns = parse_columns_arg(columns)
#     696
# --> 697     pydf = PyDataFrame.read_csv(
#     698         source,
#     699         infer_schema_length,
#
# FileNotFoundError: No such file or directory (os error 2): /content/train_clean.csv
